# %%
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# %%
llm = ChatGroq(temperature=0, groq_api_key="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", model_name="mixtral-8x7b-32768")

# %%
domain = input("Enter a domain: ")
sub_domain = input("Enter a sub-domain: ")
title = input("Enter a title for your problem: ")

# %%
prompt = ChatPromptTemplate.from_template("""
You are provided with a title, domain, and sub-domain. Use these details to create a concise abstract for the user's problem.

Domain:
```{domain}```

Sub-domain:
```{sub_domain}```

Title:
```{title}```

Your task is to generate a 30 word abstract that accurately summarizes the problem described by the title, ensuring relevance to the given domain and sub-domain.
"""
)


chain= (
    prompt
   | llm
   |StrOutputParser() )

abstract = chain.invoke({"domain": domain,"sub_domain": sub_domain,"title": title})

print(abstract)
# Out:
# "Explore the development of Solid-State Batteries in Electric Vehicles, aiming to improve energy density and safety, overcoming current limitations in range and charging time."

# %%
prompt = ChatPromptTemplate.from_template("""
You are provided with a title, domain, sub-domain, and an abstract. Use these details to create a detailed description of the user's problem.

Domain:
```{domain}```

Sub-domain:
```{sub_domain}```

Title:
```{title}```

Abstract:
```{abstract}```

Your task is to generate a comprehensive and detailed description of the problem described by the title and abstract. Ensure that the description elaborates on the key points mentioned in the abstract and is relevant to the given domain and sub-domain.
"""
)



chain= (
    prompt
   | llm
   |StrOutputParser() )

description = chain.invoke({"domain": domain,"sub_domain": sub_domain,"title": title,"abstract":abstract})

print(description)
# Out:
# The increasing adoption of electric vehicles (EVs) has highlighted the need for advancements in battery technology to address key limitations such as range and charging time. The current lithium-ion batteries used in EVs have a relatively low energy density, which impacts the vehicle's driving range and the time required for recharging. To tackle these challenges, researchers and manufacturers are investing significant efforts in the development of solid-state batteries as an alternative to conventional lithium-ion batteries.
#
# A solid-state battery is an innovative design that replaces the liquid or polymer electrolyte found in lithium-ion batteries with a solid material. This design offers several potential benefits, including increased energy density, improved safety, and longer lifespan. The solid-state battery's enhanced energy density can result in a significant increase in the driving range of EVs, addressing one of the major concerns for potential EV adopters. Additionally, solid-state batteries are less prone to overheating and fire hazards, which are associated with the flammability of liquid electrolytes in lithium-ion batteries.
#
# However, the development of solid-state batteries for EVs faces several challenges. These include:
#
# 1. Identifying suitable solid electrolyte materials with high ionic conductivity, mechanical stability, and compatibility with electrode materials.
# 2. Developing cost-effective and scalable manufacturing processes for solid-state batteries that can match the current production rates of lithium-ion batteries.
# 3. Ensuring long-term performance and reliability of solid-state batteries under various operating conditions, such as temperature fluctuations and charging cycles.
#
# In conclusion, the development of solid-state batteries for electric vehicles is a promising approach to overcome the current limitations of lithium-ion batteries. By addressing the challenges in material selection, manufacturing, and performance, solid-state batteries can significantly improve the energy density, safety, and lifespan of EV batteries, leading to a more appealing and sustainable transportation solution.

# %%
prompt = ChatPromptTemplate.from_template("""
You are provided with a title, domain, sub-domain, and an abstract. Use these details to determine the problem-type for the user's problem.

Domain:
```{domain}```

Sub-domain:
```{sub_domain}```

Title:
```{title}```

Abstract:
```{abstract}```

Your task is to identify and specify the problem-type based on the information provided. Ensure that the problem-type accurately reflects the nature of the problem described by the title and abstract, and is relevant to the given domain and sub-domain.
Just specify the problem type(2-3 words) accurately strictly in this format.
"Problem Type: ____________"
""")

# Define the chain
chain = (
    prompt
    | llm
    | StrOutputParser()
)

# Invoke the chain with the input data
problem_type = chain.invoke({
    "domain": domain,
    "sub_domain": sub_domain,
    "title": title,
    "abstract": abstract
})

# Print the determined problem type
print("Determined Problem Type:", problem_type)
# Out:
# Determined Problem Type: Problem Type: Battery Energy Density and Safety

# %%
prompt = ChatPromptTemplate.from_template("""
You are provided with a title, domain, sub-domain, and a detailed description of the problem. Use this information to generate assumptions for the user. Generate a maximum of 5 such assumptions.

Domain:
```{domain}```

Sub-domain:
```{sub_domain}```

Title:
```{title}```

Problem Type:
```{type}```                                         

Description:
```{description}```
                                                                        

Your task is to infer potential assumptions based on the provided problem details. Assumptions are underlying beliefs or conditions assumed to be true. Ensure that the generated assumptions are relevant to the given domain, sub-domain, and problem description.
""")

# Define the chain
chain = (
    prompt
    | llm
    | StrOutputParser()
)

# Invoke the chain with the input data
assumptions = chain.invoke({
    "domain": domain,
    "sub_domain": sub_domain,
    "title": title,
    "type": problem_type,
    "description": description
})

# Print the generated assumptions
print("Generated Assumptions:")
print(assumptions)
# Out:
# Generated Assumptions:
# 1. Assumption: The ongoing research and development efforts in solid-state battery technology will yield successful results, leading to the successful commercialization of solid-state batteries for electric vehicles.
#
# 2. Assumption: The identified solid electrolyte materials with high ionic conductivity, mechanical stability, and compatibility with electrode materials can be produced and sourced cost-effectively and sustainably.
#
# 3. Assumption: The development of cost-effective and scalable manufacturing processes for solid-state batteries will not compromise the performance, safety, or lifespan of the batteries, ensuring their competitiveness with conventional lithium-ion batteries.
#
# 4. Assumption: The long-term performance and reliability of solid-state batteries under various operating conditions can be guaranteed through rigorous testing, validation, and quality control measures during the manufacturing process.
#
# 5. Assumption: The increased energy density, safety, and lifespan of solid-state batteries will significantly contribute to the wider adoption of electric vehicles, leading to a more sustainable transportation solution and a reduction in greenhouse gas emissions.

# %%
prompt = ChatPromptTemplate.from_template("""
You are provided with a title, domain, sub-domain, problem type, and a detailed description of the problem. Use this information to propose experiment hypotheses for solving the problem.

Domain:
```{domain}```

Sub-domain:
```{sub_domain}```

Title:
```{title}```

Problem Type:
```{problem_type}```

Description:
```{description}```

Your task is to propose experiment hypotheses based on the provided problem details. Experiment hypotheses are proposed strategies or approaches that can be tested to solve the problem. Ensure that the generated hypotheses are relevant to the given domain, sub-domain, problem type, and description.
""")

# Define the chain
chain = (
    prompt
    | llm
    | StrOutputParser()
)


# Invoke the chain with the input data
experiment_hypotheses = chain.invoke({
    "domain": domain,
    "sub_domain": sub_domain,
    "title": title,
    "problem_type": problem_type,
    "description": description
})

# Print the generated experiment hypotheses
print("Generated Experiment Hypotheses:")
print(experiment_hypotheses)
# Out:
# Generated Experiment Hypotheses:
# Hypothesis 1:
# If we develop a solid electrolyte material with a unique nanostructure, then it will exhibit higher ionic conductivity, mechanical stability, and compatibility with electrode materials, thereby addressing the challenge of identifying suitable solid electrolyte materials.
#
# Hypothesis 2:
# By implementing a roll-to-roll manufacturing process for solid-state batteries, we can achieve cost-effective and scalable production that matches the current rates of lithium-ion batteries, thus overcoming the challenge of developing cost-effective and scalable manufacturing processes.
#
# Hypothesis 3:
# Incorporating a self-healing mechanism in solid-state batteries through the use of dynamic covalent bonds can improve the long-term performance and reliability of solid-state batteries under various operating conditions, such as temperature fluctuations and charging cycles.
#
# Hypothesis 4:
# If we combine solid-state batteries with wireless charging technology, it can potentially reduce the need for frequent charging and increase the overall convenience and usability of electric vehicles, thus further addressing the challenge of charging time and range anxiety.
#
# Hypothesis 5:
# The development of a multi-material 3D printing technique can enable the fabrication of customized solid-state batteries with optimized energy density, safety, and lifespan, tailored to specific electric vehicle models and applications.
#
# Hypothesis 6:
# Investigating the use of alternative materials, such as sodium or potassium, for solid-state batteries can lead to a reduction in material costs and potential supply chain issues, addressing the challenge of cost-effectiveness and scalability.
#
# Hypothesis 7:
# Implementing machine learning algorithms and data-driven approaches in the design and optimization of solid-state battery materials and manufacturing processes can accelerate the development of high-performing solid-state batteries by predicting and mitigating potential issues early in the design process.

# %%
def generate_abstract(domain, sub_domain, title):
    prompt = ChatPromptTemplate.from_template("""
    You are provided with a title, domain, and sub-domain. Use these details to create a concise abstract for the user's problem.

    Domain:
    ```{domain}```

    Sub-domain:
    ```{sub_domain}```

    Title:
    ```{title}```

    Your task is to generate a 30 word abstract that accurately summarizes the problem described by the title, ensuring relevance to the given domain and sub-domain.
    """
    )

    chain = (
        prompt
        | llm
        | StrOutputParser()
    )

    return chain.invoke({"domain": domain, "sub_domain": sub_domain, "title": title})

def generate_description(domain, sub_domain, title, abstract):
    prompt = ChatPromptTemplate.from_template("""
    You are provided with a title, domain, sub-domain, and an abstract. Use these details to create a detailed description of the user's problem.

    Domain:
    ```{domain}```

    Sub-domain:
    ```{sub_domain}```

    Title:
    ```{title}```

    Abstract:
    ```{abstract}```

    Your task is to generate a comprehensive and detailed description of the problem described by the title and abstract. Ensure that the description elaborates on the key points mentioned in the abstract and is relevant to the given domain and sub-domain.
    """
    )

    chain = (
        prompt
        | llm
        | StrOutputParser()
    )

    return chain.invoke({"domain": domain, "sub_domain": sub_domain, "title": title, "abstract": abstract})

def determine_problem_type(domain, sub_domain, title, abstract):
    prompt = ChatPromptTemplate.from_template("""
    You are provided with a title, domain, sub-domain, and an abstract. Use these details to determine the problem-type for the user's problem.

    Domain:
    ```{domain}```

    Sub-domain:
    ```{sub_domain}```

    Title:
    ```{title}```

    Abstract:
    ```{abstract}```

    Your task is to identify and specify the problem-type based on the information provided. Ensure that the problem-type accurately reflects the nature of the problem described by the title and abstract, and is relevant to the given domain and sub-domain.
    Just specify the problem type(2-3 words) accurately strictly in this format.
    "Problem Type: ____________"
    """
    )

    chain = (
        prompt
        | llm
        | StrOutputParser()
    )

    return chain.invoke({"domain": domain, "sub_domain": sub_domain, "title": title, "abstract": abstract})

def generate_assumptions(domain, sub_domain, title, problem_type, description):
    prompt = ChatPromptTemplate.from_template("""
    You are provided with a title, domain, sub-domain, and a detailed description of the problem. Use this information to generate assumptions for the user. Generate a maximum of 5 such assumptions.

    Domain:
    ```{domain}```

    Sub-domain:
    ```{sub_domain}```

    Title:
    ```{title}```

    Problem Type:
    ```{problem_type}```                                         

    Description:
    ```{description}```


    Your task is to infer potential assumptions based on the provided problem details. Assumptions are underlying beliefs or conditions assumed to be true. Ensure that the generated assumptions are relevant to the given domain, sub-domain, and problem description.
    """
    )

    chain = (
        prompt
        | llm
        | StrOutputParser()
    )

    return chain.invoke({"domain": domain, "sub_domain": sub_domain, "title": title, "problem_type": problem_type, "description": description})

def generate_hypotheses(domain, sub_domain, title, problem_type, description):
    prompt = ChatPromptTemplate.from_template("""
    You are provided with a title, domain, sub-domain, problem type, and a detailed description of the problem. Use this information to propose experiment hypotheses for solving the problem.

    Domain:
    ```{domain}```

    Sub-domain:
    ```{sub_domain}```

    Title:
    ```{title}```

    Problem Type:
    ```{problem_type}```

    Description:
    ```{description}```

    Your task is to propose experiment hypotheses based on the provided problem details. Experiment hypotheses are proposed strategies or approaches that can be tested to solve the problem. Ensure that the generated hypotheses are relevant to the given domain, sub-domain, problem type, and description.
    """
    )

    chain = (
        prompt
        | llm
        | StrOutputParser()
    )

    return chain.invoke({"domain": domain, "sub_domain": sub_domain, "title": title, "problem_type": problem_type, "description": description})


# Input data
domain = input("Enter a domain: ")
sub_domain = input("Enter a sub-domain: ")
title = input("Enter a title for your problem: ")

# Generate abstract
abstract = generate_abstract(domain, sub_domain, title)
print("Abstract:", abstract)

# Generate description
description = generate_description(domain, sub_domain, title, abstract)
print("Description:", description)

# Determine problem type
problem_type = determine_problem_type(domain, sub_domain, title, abstract)
print("Problem Type:", problem_type)

# Generate assumptions
assumptions = generate_assumptions(domain, sub_domain, title, problem_type, description)
print("Assumptions:", assumptions)

# Generate hypotheses
hypotheses = generate_hypotheses(domain, sub_domain, title, problem_type, description)
print("Hypotheses:", hypotheses)
# Out:
# Abstract: "Explore solid-state battery technology for electric vehicles, aiming to increase energy density, safety, and longevity, overcoming current limitations in lithium-ion batteries."
# Description: The automotive industry is currently facing a significant challenge in the sub-domain of Electric Vehicle (EV) batteries, specifically with the conventional lithium-ion batteries. These batteries, while widely used, have certain limitations such as lower energy density, safety concerns, and limited longevity. To address these issues, there is a pressing need to explore and develop advanced battery technology, and one such promising solution is the solid-state battery.
#
# The problem at hand is to improve the performance and efficiency of EV batteries by transitioning from traditional lithium-ion batteries to solid-state batteries. Solid-state batteries have the potential to revolutionize the EV industry by offering a higher energy density, enhanced safety, and increased longevity compared to their lithium-ion counterparts.
#
# Higher energy density is crucial for EVs as it directly impacts the driving range and the overall performance of the vehicle. Safety is another critical aspect, as lithium-ion batteries have been known to pose fire and explosion risks due to their flammable liquid electrolytes. Moreover, the limited lifespan of lithium-ion batteries results in reduced battery capacity over time, leading to a shorter driving range and increased replacement costs.
#
# Solid-state batteries, on the other hand, utilize a solid electrolyte instead of a liquid one, thereby eliminating the risk of leakage and fire. Additionally, solid-state batteries can provide a higher energy density due to their ability to accommodate more active material, leading to an increased driving range for EVs. Furthermore, solid-state batteries have the potential to offer a longer lifespan, reducing the overall cost of ownership and enhancing customer satisfaction.
#
# In summary, the challenge lies in developing and implementing solid-state battery technology for electric vehicles. This involves addressing technical hurdles, such as improving the conductivity of solid electrolytes, ensuring proper electrode-electrolyte interfaces, and optimizing manufacturing processes. By overcoming these challenges, the automotive industry can significantly enhance the performance, safety, and cost-effectiveness of electric vehicles, paving the way for wider adoption and a more sustainable future.
# Problem Type: Problem Type: Battery Energy Density
# Assumptions: 1. Assumption: The development of solid-state batteries will lead to a significant increase in energy density, resulting in an improved driving range for electric vehicles.
#
# 2. Assumption: Solid-state batteries, with their non-flammable solid electrolytes, will provide enhanced safety compared to conventional lithium-ion batteries, thereby reducing the risk of fire and explosion.
#
# 3. Assumption: The use of solid-state batteries in electric vehicles will result in a longer lifespan, reducing battery replacement costs and increasing customer satisfaction.
#
# 4. Assumption: Overcoming technical challenges, such as improving the conductivity of solid electrolytes and optimizing manufacturing processes, is critical for the successful implementation of solid-state battery technology in the automotive industry.
#
# 5. Assumption: Widespread adoption of solid-state batteries in electric vehicles will contribute to a more sustainable future by reducing greenhouse gas emissions and reliance on fossil fuels.
# Hypotheses: Hypothesis 1:
# Increasing the conductivity of solid electrolytes in solid-state batteries will result in improved charge/discharge rates and overall battery efficiency, thereby enhancing the driving range of electric vehicles.
#
# Hypothesis 2:
# Developing advanced coating techniques for electrode-electrolyte interfaces in solid-state batteries will optimize the interaction between the electrodes and the solid electrolyte, leading to improved energy density and longevity.
#
# Hypothesis 3:
# Implementing innovative manufacturing processes, such as roll-to-roll or 3D printing, for solid-state batteries will reduce production costs, increase scalability, and enable wider adoption of this technology in the electric vehicle industry.
#
# Hypothesis 4:
# Integrating smart battery management systems with solid-state batteries will enable real-time monitoring of battery performance, allowing for predictive maintenance, increased safety, and prolonged battery life.
#
# Hypothesis 5:
# Collaborating with materials scientists and engineers to explore and develop new solid electrolyte materials, such as sulfides or halides, will address current limitations in solid-state battery technology, resulting in enhanced energy density, safety, and longevity.
#
# Hypothesis 6:
# Investigating the use of alternative anode materials, such as lithium metal or silicon, in solid-state batteries will further increase energy density, driving range, and overall performance of electric vehicles.
#
# Hypothesis 7:
# Designing solid-state batteries with a modular architecture will allow for easy replacement or upgrading of individual components, reducing total cost of ownership and increasing customer satisfaction in the electric vehicle market.
